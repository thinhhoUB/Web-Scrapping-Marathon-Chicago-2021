# %% [markdown]
# # Introduction:

# %% [markdown]
# Yearly, the **city of Chicago** host a their famous **marathon competition** with the participation of thousands of people. And 2021 is not an exception, there is a website **results.chicagomarathon.com/well-known/2021/** which contains all the records of 2021 competition.
#
# For this project, we are interested in **scrapping** the information of the **top 50 male runners** by utilizing **request** and **BeautifulSoup**. More detail, we will collect their:
# > - name
# > - age group
# > - bib number
# > - age
# > - city/state
# > - split times

# %% [markdown]
# # Scrapping process :

# %% [markdown]
# ### General Information:

# %% [markdown]
# Importing **requests** library and use it to connect to a web page:

# %%
import requests

# %% [markdown]
# Send a **GET** request to a result website and download a **HTML** content:

# %%
records= requests.get('https://results.chicagomarathon.com/2021/?lang=EN_CAP&num_results=50&pid=list&pidp=start&search%5Bsex%5D=M&search%5Bage_class%5D=%25&event=MAR&favorite_add=LSMG96382434CB').text

# %% [markdown]
# Importing a library **BeautifulSoup**, create an instance, and **parse** our HTML document:

# %%
from bs4 import BeautifulSoup
soup= BeautifulSoup(records)

# %% [markdown]
# Here, we can now **print** out the HTML content of the page, **formatted nicely**, using the **prettify method** on the BeautifulSoup object:

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Bank of America Chicago Marathon
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
#   <link href="//results-static.mikatiming.com/2021/chicago/../../stages/blue/images/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="198023663696085" property="fb:app_id"/>
#   <meta content="https://results-static.mikatiming.com/2021/chicago/styles/responsive_2016/logo_fb.png" property="og:image"/>
#   <meta content="630" property="og:image:width"/>
#   <meta content="315" property="og:image:height"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Mika timing" property="og:site_name"/>
#   <meta content="https://results.chicagomarathon.com/2021/?event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25" property="og:url"/>
#   <meta content="Bank of America Chicago Marathon: Results" property="og:title"/>
#   <link href="//results-static.mikatiming.com/stages/blue/lib/static/bootstrap-3.3.7/css/bootstrap.css" rel="stylesheet"/>
#   <link href="//results-static.mikatiming.com/stages/blue/lib/static/styles.build/responsive_2016/style.css" rel="stylesheet"/>
#   <link href="/2021/?content=css_event&amp;theme=responsive&amp;event=2021_chicago&amp;style=responsive_2016" rel="stylesheet" type="text/css"/>
#   <link href="//results-static.mikatiming.com/stages/blue/images/favicon.ico" rel="shortcut icon"/>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js" type="text/javascript">
#   </script>
#   <script src="//results-static.mikatiming.com/stages/blue/lib/static/bootstrap-3.3.7/js/bootstrap.min.js">
#   </script>
#   <script src="/2021/?content=ajax2&amp;client=js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var require = {"baseUrl":"\/\/results-static.mikatiming.com\/stages\/blue\/lib\/static","deps":["\/\/results-static.mikatiming.com\/stages\/blue\/lib\/static\/webcomponentsjs-0.7.0\/webcomponents-lite.js"],"paths":{"d3":"d3-3.4.13\/d3","c3":"c3-0.4.8\/c3","moment":"moment.js-2.9.0\/moment-with-locales.min","GDouglasPeuker":"GDouglasPeuker","Mika":"Mika.build","async":"require.js-plugins-1.0.3\/async","combokeys":"combokeys-2.3.0\/dist\/combokeys","videojs":"video.js-5.10.8\/dist\/video","hls":"videojs-contrib-hls","hls2":"videojs5-hlsjs-source-handler\/dist\/videojs5-hlsjs-source-handler","nouislider":"noUiSlider-9.2.0\/nouislider.min","screenfull":"screenfull.js-4.0.0\/screenfull","lodashIsEqual":"lodash\/isEqual","Mika\/Dialog":"Mika.build\/Dialog.js?d3faaa3a53","Mika\/Environment":"Mika.build\/Environment.js?deef9c612c","Mika\/FavoriteColorMapper":"Mika.build\/FavoriteColorMapper.js?9ea506e25e","Mika\/ImageErrorHandler":"Mika.build\/ImageErrorHandler.js?e55b4d047c","Mika\/ImageViewer":"Mika.build\/ImageViewer.js?567a6ee86e","Mika\/Logger":"Mika.build\/Logger.js?7001107a61","Mika\/Map\/FavoriteBar":"Mika.build\/Map\/FavoriteBar.js?d
#   </script>
#   <script src="//results-static.mikatiming.com/stages/blue/lib/static/require.js-2.3.6/require.min.js" type="text/javascript">
#   </script>
#   <script src="//results-static.mikatiming.com/stages/blue/lib/static/Emitter.js" type="text/javascript">
#   </script>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <script type="text/javascript">
#    // create helper function to handle the image loading errors
#         var mikaImageErrorHandler = function (image) {
#             require(["Mika/ImageErrorHandler"], function (ImageErrorHandler) {
#                 var que = ImageErrorHandler.queueImageGeneration(image.dataset.generateSrcUrl, image.dataset.imageHash, image.src);
#                 setTimeout(function () {
#                      ImageErrorHandler.statusMissingImages(que);
#                 }, 1100);
#             })
#         };
#         require(["Mika/Mika", "require"], function (Mika, require) {
#             new Mika();
#             require(["Mika/Dialog", "Mika/Popover", "Mika/ImageViewer", "Mika/Timer"]);
#         });
#   </script>
#  </head>
#  <body class="pid-list content-list view-public branch-production site-2021_chicago event-MAR">
#   <header class="hidden-xs">
#    <div class="container">
#     <div class="logo row">
#      <a href="/2021/?lang=EN_CAP&amp;pidp=start">
#       <img alt="" class="logo-screen" src="//results-static.mikatiming.com/2021/chicago/../chicago/styles/responsive_2016/logo.png"/>
#      </a>
#      <ul class="header-brand">
#       <li>
#        Race Results
#       </li>
#       <li>
#        Unofficial Race Results
#       </li>
#       <li>
#        Start Time: 07:30:00
#       </li>
#      </ul>
#     </div>
#    </div>
#   </header>
#   <nav class="navbar navbar-default navbar-top navbar-fixed-top">
#    <div class="container">
#     <div class="navbar-header">
#      <button aria-expanded="false" class="navbar-toggle collapsed" data-target="#navbar" data-toggle="collapse" type="button">
#       <span class="sr-only">
#        Toggle navigation
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#      </button>
#      <a class="navbar-brand" href="/2021/?lang=EN_CAP&amp;pidp=start">
#       <img alt="" class="hidden-sm hidden-md hidden-lg" src="//results-static.mikatiming.com/2021/chicago/../chicago/styles/responsive_2016/logo.png"/>
#       <span class="hidden-xs">
#        Bank of America Chicago Marathon 2021
#       </span>
#      </a>
#     </div>
#     <div class="navbar-collapse collapse" id="navbar">
#      <ul class="nav navbar-nav hidden-sm hidden-md hidden-lg">
#       <li class="active">
#        <a class="nav-pid-start" href="/2021/?event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pid=start&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25">
#         <span>
#          Results
#         </span>
#        </a>
#       </li>
#       <li>
#        <a class="nav-pid-leaderboard" href="/2021/?lang=EN_CAP&amp;pid=leaderboard&amp;pidp=start">
#         <span>
#          Leaderboard
#         </span>
#        </a>
#       </li>
#       <li>
#        <a class="nav-pid-leaderboard_sprint" href="/2021/?lang=EN_CAP&amp;pid=leaderboard_sprint&amp;pidp=start">
#         <span>
#          Bonus Competition
#         </span>
#        </a>
#       </li>
#       <li>
#        <a class="nav-pid-tracking" href="/2021/?lang=EN_CAP&amp;pid=tracking&amp;pidp=start">
#         <span>
#          Tracking
#         </span>
#        </a>
#       </li>
#       <li>
#        <a class="nav-pid-favorites" href="/2021/?lang=EN_CAP&amp;pid=favorites&amp;pidp=start">
#         <span>
#          My Runners
#         </span>
#        </a>
#       </li>
#      </ul>
#      <ul class="nav navbar-nav navbar-right">
#       <li class="">
#        <a class="" href="https://chicago-history.r.mikatiming.com/" role="button">
#         to Results 1996-2019
#        </a>
#       </li>
#       <li class="">
#        <a class="" href="http://www.chicagomarathon.com/" role="button">
#         Back to Homepage
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#   </nav>
#   <!-- header end -->
#   <!-- main start -->
#   <script type="text/javascript">
#    //<![CDATA[
# var _gaq=_gaq||[];var ga_track={};ga_track.trackersArray=new Array();ga_track.push=function(){var arr=[],ta=ga_track.trackersArray;arr.push.apply(arr,arguments);for(var t=ta.length-1;t>-1;--t){for(var i=arr.length-1;i>-1;--i){var _pos=arr[i][0].indexOf('_');arr[i][0]=(_pos<1)?(ta[t]+arr[i][0]):(ta[t]+arr[i][0].substr(_pos));_gaq.push(arr[i]);}}};
# _gaq.push(['_gat._anonymizeIp']);
# _gaq.push(['t0._setAccount', 'UA-8939914-17']);
# _gaq.push(['t0._setCustomVar', 1, 'Event', 'MAR']);
# _gaq.push(['t0._trackPageview', '/2021_chicago' + window.location.pathname + window.location.search + window.location.hash]);
# ga_track.trackersArray.push('t0.');
# _gaq.push(['t1._setAccount', 'UA-8939914-1']);
# _gaq.push(['t1._setCustomVar', 1, 'Event', 'MAR']);
# _gaq.push(['t1._trackPageview', '/2021_chicago' + window.location.pathname + window.location.search + window.location.hash]);
# ga_track.trackersArray.push('t1.');
#
#         (function () {
#             var ga = document.createElement('script');
#             ga.type = 'text/javascript';
#             ga.async = true;
#             ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#             var s = document.getElementsByTagName('script')[0];
#             s.parentNode.insertBefore(ga, s);
#         })();
#
#         //]]>
#   </script>
#   <section class="section-nav container-fluid">
#    <nav class="navbar navbar-default row navbar-main hidden-xs">
#     <div class="container">
#      <ul class="nav navbar-nav">
#       <li class="active nav-pid-start">
#        <a href="/2021/?lang=EN_CAP&amp;pid=start&amp;pidp=start">
#         <span>
#          Results
#         </span>
#        </a>
#       </li>
#       <li class="nav-pid-leaderboard">
#        <a href="/2021/?lang=EN_CAP&amp;pid=leaderboard&amp;pidp=leaderboard">
#         <span>
#          Leaderboard
#         </span>
#        </a>
#       </li>
#       <li class="nav-pid-leaderboard_sprint">
#        <a href="/2021/?lang=EN_CAP&amp;pid=leaderboard_sprint&amp;pidp=leaderboard_sprint">
#         <span>
#          Bonus Competition
#         </span>
#        </a>
#       </li>
#       <li class="nav-pid-tracking">
#        <a href="/2021/?lang=EN_CAP&amp;pid=tracking&amp;pidp=tracking">
#         <span>
#          Tracking
#         </span>
#        </a>
#       </li>
#       <li class="nav-pid-favorites">
#        <a href="/2021/?lang=EN_CAP&amp;pid=favorites&amp;pidp=favorites">
#         <span>
#          My Runners
#         </span>
#        </a>
#       </li>
#       <li class="dropdown hide">
#        <a aria-expanded="true" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="javascript:void(0);" id="navbar-main-dropdown">
#         More
#         <span class="caret">
#         </span>
#        </a>
#        <ul aria-labelledby="navbar-main-dropdown" class="dropdown-menu">
#        </ul>
#       </li>
#       <script type="text/javascript">
#        jQuery("#navbar-main-dropdown").dropdown();
#                 var menuResizeHandler = function () {
#                     var container   = jQuery(".navbar-main .container");
#                     var navbar   = jQuery(".navbar-main .nav");
#                     var currentWidth = 0;
#                     var dropdown = navbar.find("li.dropdown");
#                     // quickly show it and get the width
#                     dropdown.removeClass("hide");
#                     var dropdownWidth = dropdown.width();
#                     var quicksearchWidth = jQuery(".navbar-main .quicksearch-form").width();
#                     currentWidth += quicksearchWidth;
#                     var menuEntries = navbar.find("li:not(.dropdown)");
#                     menuEntries.each(function (i) {
#                         navbar.append(this);
#                     });
#                     navbar.append(dropdown);
#                     dropdown.addClass("hide").removeClass("active");
#
#                     var maxWidth = container.width();
#                     menuEntries.each(function (i) {
#                         currentWidth += jQuery(this).width();
#
#                         var next = false;
#                         if (typeof menuEntries[i+1] !== "undefined") {
#                             next = menuEntries[i+1];
#                         }
#                         var currentIsAboveMaxWidth = (currentWidth > maxWidth);
#                         var currentIsNotLastAndPlusDropdownIsAboveMaxWidth = ((currentWidth + dropdownWidth > maxWidth) && i != menuEntries.length-1);
#                         var currentPlusNextIsAboveMaxWidth = (next && currentWidth + jQuery(next).width() > maxWidth);
#                         //console.log("%s: width: %s, is above: %s, notlast: %s, plusnext: %s", jQuery(this).text(), currentWidth, currentIsAboveMaxWidth, currentIsNotLastAndPlusDropdownIsAboveMaxWidth, currentPlusNextIsAboveMaxWidth)
#                         if(currentIsAboveMaxWidth || currentIsNotLastAndPlusDropdownIsAboveMaxWidth || currentPlusNextIsAboveMaxWidth) {
#                             jQuery(this).find("a").popover("destroy");
#                             dropdown.find("ul").append(this);
#                             dropdown.removeClass("hide");
#                             if (jQuery(this).hasClass("active")) {
#                                 dropdown.addClass("active");
#                             }
#                         }
#                     });
#
#                 };
#                 jQuery(document).on("ready", menuResizeHandler);
#                 var lastWidth = 0;
#                 jQuery(window).on("resize", function () {
#                     lastWidth = window.innerWidth;
#                     setTimeout(function () {
#                         if (lastWidth == window.innerWidth) {
#                             menuResizeHandler();
#                         }
#                     }, 100);
#                 });
#       </script>
#      </ul>
#     </div>
#    </nav>
#    <!-- menu end -->
#   </section>
#   <section class="section-main">
#    <div class="container" id="main-content">
#     <div class="row">
#      <div class="cbox-main pid-list col-xs-12" id="cbox-main">
#       <!-- cbox include start -->
#       <div class="row">
#        <div class="col-xs-10">
#         <h2>
#          Results: Marathon
#         </h2>
#        </div>
#       </div>
#       <ul class="row-xs list-group list-info">
#        <li class="list-group-item">
#         Unofficial Results |
#         <span class="sex">
#          Men
#         </span>
#        </li>
#       </ul>
#       <div class="col-sm-12 row-xs">
#        <ul class="list-group list-group-multicolumn">
#         <li class="list-group row list-group-item list-group-header">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs" style="width: 40px">
#             Place Overall
#            </div>
#            <div class="list-field type-place place-primary" style="width: 40px">
#             Place Gender
#            </div>
#            <div class="list-field type-fullname">
#             Name (CTZ)
#            </div>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 hidden-xs hidden-sm list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              BIB
#             </div>
#             <div class="list-field type-age_class" style="width: 90px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              Division
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              HALF
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              Finish
#             </div>
#             <div class="list-field type-favorite" style="width: 13px">
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-active list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             1
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             1
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=LSMG963824DD5C&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Tura Abdiwak, Seifu (ETH)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              3
#             </div>
#             <div class="list-field type-age_class" style="width: 90px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              20-24
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:02:29
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:06:12
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=LSMG963824DD5C">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             2
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             2
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=LSMG963824DD61&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Rupp, Galen (USA)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              9
#             </div>
#             <div class="list-field type-age_class" style="width: 90px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              35-39
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:02:40
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:06:35
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=LSMG963824DD61">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-active list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             3
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             3
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=LSMG963824DD60&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Kiptanui, Eric (KEN)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              7
#             </div>
#             <div class="list-field type-age_class" style="width: 90px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              30-34
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:02:29
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:06:51
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=LSMG963824DD60">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             4
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             4
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=LSMG963824DD5E&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Suzuki, Kengo (JPN)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              5
#             </div>
#             <div class="list-field type-age_class" style="width: 90px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              25-29
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:02:30
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:08:50
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=LSMG963824DD5E">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-active list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             5
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             5
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=LSMG963824DD5F&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Tamru Aredo, Shifera (ETH)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              6
#             </div>
#             <div class="list-field type-age_class" style="width: 90px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              20-24
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:02:29
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:09:39
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=LSMG963824DD5F">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             6
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             6
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=LSMG963824DD95&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Mickow, Colin (USA)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              15
#             </div>
#             <div class="list-field type-age_class" style="width: 90px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              30-34
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:06:11
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:13:31
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=LSMG963824DD95">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-active list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             7
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             7
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=LSMG963824DD53&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Montanez, Nico (USA)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              22
#             </div>
#             <div class="list-field type-age_class" style="width: 90px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              25-29
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:06:11
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:13:55
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=LSMG963824DD53">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             8
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             8
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=LSMG963824DD5B&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Kipyego, Reuben Kiprop (KEN)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              2
#             </div>
#             <div class="list-field type-age_class" style="width: 90px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              25-29
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:02:29
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:14:24
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=LSMG963824DD5B">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-active list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             9
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             9
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=LSMG963824DD6C&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Fischer, Reed (USA)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              30
#             </div>
#             <div class="list-field type-age_class" style="width: 90px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              25-29
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:07:17
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:14:41
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=LSMG963824DD6C">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             10
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             10
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=LSMG963824DD67&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Given, Wilkerson (USA)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              16
#             </div>
#             <div class="list-field type-age_class" style="width: 90px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              30-34
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:06:11
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:14:55
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=LSMG963824DD67">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-active list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             11
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             11
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=LSMG963824DD71&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Panning, Zachery (USA)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              35
#             </div>
#             <div class="list-field type-age_class" style="width: 90px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              25-29
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:07:58
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:15:04
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=LSMG963824DD71">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             12
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             12
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=LSMG963824DD73&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Thomson, Jacob (USA)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              37
#             </div>
#             <div class="list-field type-age_class" style="width: 90px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              25-29
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:06:51
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:15:49
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=LSMG963824DD73">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-active list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             13
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             13
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=LSMG963824DD6D&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Young, Clayton (USA)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
# ...
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             51
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             46
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=LSMG96382434F8&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Fanta, Gizachew (ISR)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              483
#             </div>
#             <div class="list-field type-age_class" style="width: 90px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              30-34
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:11:40
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:29:15
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=LSMG96382434F8">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-active list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             52
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             47
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=LSMG96382434DD&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Craighead, Daniel (USA)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              455
#             </div>
#             <div class="list-field type-age_class" style="width: 90px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              30-34
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:10:44
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:29:21
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=LSMG96382434DD">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             53
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             48
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=LSMG9638243623&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Martinez, Juan (COL)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              1128
#             </div>
#             <div class="list-field type-age_class" style="width: 90px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              30-34
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:14:27
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:29:57
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=LSMG9638243623">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-active list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             54
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             49
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=LSMG9638243633&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Cowlin, Joe (USA)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              713
#             </div>
#             <div class="list-field type-age_class" style="width: 90px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              25-29
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:13:59
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:30:12
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=LSMG9638243633">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="favorite list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             55
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             50
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=LSMG96382434CB&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Williams, Nathanael (USA)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              698
#             </div>
#             <div class="list-field type-age_class" style="width: 90px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              25-29
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:10:25
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:30:13
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_remove=LSMG96382434CB">
#               <img alt="Remove Runner from 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/delete.svg" title="Remove Runner from 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#        </ul>
#       </div>
#       <div class="row">
#        <div class="col-xs-8 col-sm-9 col-md-6">
#         <div aria-label="" class="btn-toolbar list-actions" role="toolbar">
#          <div class="btn-group" role="group">
#           <a class="btn btn-default" href="?pid=start&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25">
#            Back / New Search
#           </a>
#           <a class="btn btn-default hidden-xs" href="?event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25">
#            Reload
#           </a>
#           <a class="btn btn-default hidden-xs" href="#" onclick="open_print('?print=1&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25');">
#            Print
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="col-xs-4 col-sm-3 col-md-6">
#         <div class="pull-right pages">
#          <ul class="pagination">
#           <li class="hidden-xs hidden-sm active">
#            <a href="?page=1&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25">
#             1
#            </a>
#           </li>
#           <li class="hidden-xs hidden-sm">
#            <a href="?page=2&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25">
#             2
#            </a>
#           </li>
#           <li class="hidden-xs hidden-sm">
#            <a href="?page=3&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25">
#             3
#            </a>
#           </li>
#           <li class="disabled">
#            <a aria-label="" class="hidden-xs hidden-sm" href="#">
#             <span aria-hidden="true">
#              ...
#             </span>
#            </a>
#           </li>
#           <li class="hidden-xs hidden-sm">
#            <a href="?page=285&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25">
#             285
#            </a>
#           </li>
#           <li class="pages-nav-button">
#            <a href="?page=2&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25">
#             &gt;
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#       <!-- cbox include end -->
#      </div>
#     </div>
#     <!-- row -->
#    </div>
#    <!-- container main-content -->
#   </section>
#   <!-- section-main -->
#   <!-- main end -->
#   <!-- footer start -->
#   <footer>
#    <div class="container">
#     <div class="row">
#      <div class="footer-box legal-footer" id="pid-list">
#       <div class="col-xs-12">
#        <a class="pull-right" href="https://www.mikatiming.de/">
#         mika:timing GmbH © 2022
#        </a>
#        <a href="https://www.mikatiming.de/en/service/legal-notice/">
#         Legal Notice
#        </a>
#        |
#        <a href="https://www.mikatiming.de/en/service/legal-notice/privacy-policy/">
#         Privacy Policy
#        </a>
#       </div>
#      </div>
#     </div>
#     <!-- row end -->
#    </div>
#    <!-- container end -->
#   </footer>
#   <!-- footer section end -->
#   <div class="popup-info" id="popup-info" style="display:none;">
#   </div>
#   <div class="popup" id="popup" style="display:none;">
#   </div>
#  </body>
# </html>
# <!-- footer end -->

# %% [markdown]
# Now, we can notice that every runner is wrap with the tag **h4** and the class of **list-field type-fullname**, hence, we can obtain the array of all **50 runners** using **find_all** method:

# %%
runners=soup.find_all("h4",class_="list-field type-fullname")

# %% [markdown]
# **Checking** if we successfully have a correct numbers of runners:

# %%
len(runners)
# Out:
# 50

# %% [markdown]
# Taking a look at the **format** of the first runner in the list:

# %%
runners[0]
# Out:
# <h4 class="list-field type-fullname"><a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=LSMG963824DD5C&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">Tura Abdiwak, Seifu (ETH)</a></h4>

# %% [markdown]
# As we have here, this website only provide us **general information** such as **name**. However, we have **website** which lead to a new page contains all the **details** of each runner.

# %% [markdown]
# ### Detail information:

# %% [markdown]
# First, we will **only** scrap the information of the first runner as an example and **generalize** the process to obtain **all the runners** later

# %% [markdown]
# We want to get the **personal** link of the runner:

# %%
tail=runners[0].find('a').get('href')
tail
# Out:
# '?content=detail&fpid=list&pid=list&idp=LSMG963824DD5C&lang=EN_CAP&event=MAR&lang=EN_CAP&num_results=50&pidp=start&search%5Bsex%5D=M&search%5Bage_class%5D=%25&search_event=MAR'

# %% [markdown]
# Adding the **head** of the link to get the **complete** link

# %%
link= "https://results.chicagomarathon.com/2021/"+tail
link
# Out:
# 'https://results.chicagomarathon.com/2021/?content=detail&fpid=list&pid=list&idp=LSMG963824DD5C&lang=EN_CAP&event=MAR&lang=EN_CAP&num_results=50&pidp=start&search%5Bsex%5D=M&search%5Bage_class%5D=%25&search_event=MAR'

# %% [markdown]
# Now, we can again send a **GET** request and download the HTML content of the web page:

# %%
l= requests.get(link).text

# %% [markdown]
# Parse the HTML content with the BeautifulSoup and print out **nicely** with `prettify` method:

# %%
soup_1= BeautifulSoup(l)

# %%
print(soup_1.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Bank of America Chicago Marathon
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
#   <link href="//results-static.mikatiming.com/2021/chicago/../../stages/blue/images/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="198023663696085" property="fb:app_id"/>
#   <meta content="https://results-static.mikatiming.com/2021/chicago/styles/responsive_2016/logo_fb.png" property="og:image"/>
#   <meta content="630" property="og:image:width"/>
#   <meta content="315" property="og:image:height"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Mika timing" property="og:site_name"/>
#   <meta content="https://results.chicagomarathon.com/2021/?content=detail&amp;event=MAR&amp;idp=LSMG963824DD5C&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25" property="og:url"/>
#   <meta content="Bank of America Chicago Marathon: Seifu Tura Abdiwak Details" property="og:title"/>
#   <link href="//results-static.mikatiming.com/stages/blue/lib/static/bootstrap-3.3.7/css/bootstrap.css" rel="stylesheet"/>
#   <link href="//results-static.mikatiming.com/stages/blue/lib/static/styles.build/responsive_2016/style.css" rel="stylesheet"/>
#   <link href="/2021/?content=css_event&amp;theme=responsive&amp;event=2021_chicago&amp;style=responsive_2016" rel="stylesheet" type="text/css"/>
#   <link href="//results-static.mikatiming.com/stages/blue/images/favicon.ico" rel="shortcut icon"/>
#   <script charset="utf-8" src="//js.api.here.com/v3/3.0/mapsjs-core.js" type="text/javascript">
#   </script>
#   <script charset="utf-8" src="//js.api.here.com/v3/3.0/mapsjs-service.js" type="text/javascript">
#   </script>
#   <script charset="utf-8" src="//js.api.here.com/v3/3.0/mapsjs-ui.js" type="text/javascript">
#   </script>
#   <script charset="utf-8" src="//js.api.here.com/v3/3.0/mapsjs-mapevents.js" type="text/javascript">
#   </script>
#   <link href="//js.api.here.com/v3/3.0/mapsjs-ui.css" rel="stylesheet" type="text/css"/>
#   <link href="//results-static.mikatiming.com/stages/blue/lib/static/noUiSlider-9.2.0/nouislider.min.css" rel="stylesheet" type="text/css"/>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js" type="text/javascript">
#   </script>
#   <script src="//results-static.mikatiming.com/stages/blue/lib/static/bootstrap-3.3.7/js/bootstrap.min.js">
#   </script>
#   <script src="/2021/?content=ajax2&amp;client=js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var require = {"baseUrl":"\/\/results-static.mikatiming.com\/stages\/blue\/lib\/static","deps":["\/\/results-static.mikatiming.com\/stages\/blue\/lib\/static\/webcomponentsjs-0.7.0\/webcomponents-lite.js"],"paths":{"d3":"d3-3.4.13\/d3","c3":"c3-0.4.8\/c3","moment":"moment.js-2.9.0\/moment-with-locales.min","GDouglasPeuker":"GDouglasPeuker","Mika":"Mika.build","async":"require.js-plugins-1.0.3\/async","combokeys":"combokeys-2.3.0\/dist\/combokeys","videojs":"video.js-5.10.8\/dist\/video","hls":"videojs-contrib-hls","hls2":"videojs5-hlsjs-source-handler\/dist\/videojs5-hlsjs-source
Plugins\/list.js?c0f206e228","Mika\/Results\/Plugins\/list_responsive":"Mika.build\/Results\/Plugins\/list_responsive.js?2f3390ad8a","Mika\/Results\/Plugins\/main_buttons":"Mika.build\/Results\/Plugins\/main_buttons.js?31c6c71ea5","Mika\/Results\/Plugins\/map":"Mika.build\/Results\/Plugins\/map.js?32ee427b17","Mika\/Results\/Plugins\/overlays":"Mika.build\/Results\/Plugins\/overlays.js?1a1310bae4","Mika\/Results\/Plugins\/pacegraph":"Mika.build\/Results\/Plugins\/pacegraph.js?5718fbf289","Mika\/Results\/Plugins\/race_flow_table":"Mika.build\/Results\/Plugins\/race_flow_table.js?5d59ab07f3","Mika\/Results\/Plugins\/remote_content":"Mika.build\/Results\/Plugins\/remote_content.js?8621e4207d","Mika\/Results\/Plugins\/strings":"Mika.build\/Results\/Plugins\/strings.js?0562283c52","Mika\/Results\/Requester":"Mika.build\/Results\/Req ...
#   </script>
#   <script src="//results-static.mikatiming.com/stages/blue/lib/static/require.js-2.3.6/require.min.js" type="text/javascript">
#   </script>
#   <script src="//results-static.mikatiming.com/stages/blue/lib/static/Emitter.js" type="text/javascript">
#   </script>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <script type="text/javascript">
#    // create helper function to handle the image loading errors
#         var mikaImageErrorHandler = function (image) {
#             require(["Mika/ImageErrorHandler"], function (ImageErrorHandler) {
#                 var que = ImageErrorHandler.queueImageGeneration(image.dataset.generateSrcUrl, image.dataset.imageHash, image.src);
#                 setTimeout(function () {
#                      ImageErrorHandler.statusMissingImages(que);
#                 }, 1100);
#             })
#         };
#         require(["Mika/Mika", "require"], function (Mika, require) {
#             new Mika();
#             require(["Mika/Dialog", "Mika/Popover", "Mika/ImageViewer", "Mika/Timer"]);
#         });
#   </script>
#  </head>
#  <body class="pid-list content-detail view-public branch-production site-2021_chicago event-MAR">
#   <header class="hidden-xs">
#    <div class="container">
#     <div class="logo row">
#      <a href="/2021/?lang=EN_CAP&amp;pidp=start">
#       <img alt="" class="logo-screen" src="//results-static.mikatiming.com/2021/chicago/../chicago/styles/responsive_2016/logo.png"/>
#      </a>
#      <ul class="header-brand">
#       <li>
#        Race Results
#       </li>
#       <li>
#        Unofficial Race Results
#       </li>
#       <li>
#        Start Time: 07:30:00
#       </li>
#      </ul>
#     </div>
#    </div>
#   </header>
#   <nav class="navbar navbar-default navbar-top navbar-fixed-top">
#    <div class="container">
#     <div class="navbar-header">
#      <button aria-expanded="false" class="navbar-toggle collapsed" data-target="#navbar" data-toggle="collapse" type="button">
#       <span class="sr-only">
#        Toggle navigation
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#      </button>
#      <a class="navbar-brand" href="/2021/?lang=EN_CAP&amp;pidp=start">
#       <img alt="" class="hidden-sm hidden-md hidden-lg" src="//results-static.mikatiming.com/2021/chicago/../chicago/styles/responsive_2016/logo.png"/>
#       <span class="hidden-xs">
#        Bank of America Chicago Marathon 2021
#       </span>
#      </a>
#     </div>
#     <div class="navbar-collapse collapse" id="navbar">
#      <ul class="nav navbar-nav hidden-sm hidden-md hidden-lg">
#       <li class="active">
#        <a class="nav-pid-start" href="/2021/?event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pid=start&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25">
#         <span>
#          Results
#         </span>
#        </a>
#       </li>
#       <li>
#        <a class="nav-pid-leaderboard" href="/2021/?lang=EN_CAP&amp;pid=leaderboard&amp;pidp=start">
#         <span>
#          Leaderboard
#         </span>
#        </a>
#       </li>
#       <li>
#        <a class="nav-pid-leaderboard_sprint" href="/2021/?lang=EN_CAP&amp;pid=leaderboard_sprint&amp;pidp=start">
#         <span>
#          Bonus Competition
#         </span>
#        </a>
#       </li>
#       <li>
#        <a class="nav-pid-tracking" href="/2021/?lang=EN_CAP&amp;pid=tracking&amp;pidp=start">
#         <span>
#          Tracking
#         </span>
#        </a>
#       </li>
#       <li>
#        <a class="nav-pid-favorites" href="/2021/?lang=EN_CAP&amp;pid=favorites&amp;pidp=start">
#         <span>
#          My Runners
#         </span>
#        </a>
#       </li>
#      </ul>
#      <ul class="nav navbar-nav navbar-right">
#       <li class="">
#        <a class="" href="https://chicago-history.r.mikatiming.com/" role="button">
#         to Results 1996-2019
#        </a>
#       </li>
#       <li class="">
#        <a class="" href="http://www.chicagomarathon.com/" role="button">
#         Back to Homepage
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#   </nav>
#   <!-- header end -->
#   <!-- main start -->
#   <script type="text/javascript">
#    //<![CDATA[
# var _gaq=_gaq||[];var ga_track={};ga_track.trackersArray=new Array();ga_track.push=function(){var arr=[],ta=ga_track.trackersArray;arr.push.apply(arr,arguments);for(var t=ta.length-1;t>-1;--t){for(var i=arr.length-1;i>-1;--i){var _pos=arr[i][0].indexOf('_');arr[i][0]=(_pos<1)?(ta[t]+arr[i][0]):(ta[t]+arr[i][0].substr(_pos));_gaq.push(arr[i]);}}};
# _gaq.push(['_gat._anonymizeIp']);
# _gaq.push(['t0._setAccount', 'UA-8939914-17']);
# _gaq.push(['t0._setCustomVar', 1, 'Event', 'MAR']);
# _gaq.push(['t0._trackPageview', '/2021_chicago' + window.location.pathname + window.location.search + window.location.hash]);
# ga_track.trackersArray.push('t0.');
# _gaq.push(['t1._setAccount', 'UA-8939914-1']);
# _gaq.push(['t1._setCustomVar', 1, 'Event', 'MAR']);
# _gaq.push(['t1._trackPageview', '/2021_chicago' + window.location.pathname + window.location.search + window.location.hash]);
# ga_track.trackersArray.push('t1.');
#
#         (function () {
#             var ga = document.createElement('script');
#             ga.type = 'text/javascript';
#             ga.async = true;
#             ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#             var s = document.getElementsByTagName('script')[0];
#             s.parentNode.insertBefore(ga, s);
#         })();
#
#         //]]>
#   </script>
#   <section class="section-nav container-fluid">
#    <nav class="navbar navbar-default row navbar-main hidden-xs">
#     <div class="container">
#      <ul class="nav navbar-nav">
#       <li class="active nav-pid-start">
#        <a href="/2021/?lang=EN_CAP&amp;pid=start&amp;pidp=start">
#         <span>
#          Results
#         </span>
#        </a>
#       </li>
#       <li class="nav-pid-leaderboard">
#        <a href="/2021/?lang=EN_CAP&amp;pid=leaderboard&amp;pidp=leaderboard">
#         <span>
#          Leaderboard
#         </span>
#        </a>
#       </li>
#       <li class="nav-pid-leaderboard_sprint">
#        <a href="/2021/?lang=EN_CAP&amp;pid=leaderboard_sprint&amp;pidp=leaderboard_sprint">
#         <span>
#          Bonus Competition
#         </span>
#        </a>
#       </li>
#       <li class="nav-pid-tracking">
#        <a href="/2021/?lang=EN_CAP&amp;pid=tracking&amp;pidp=tracking">
#         <span>
#          Tracking
#         </span>
#        </a>
#       </li>
#       <li class="nav-pid-favorites">
#        <a href="/2021/?lang=EN_CAP&amp;pid=favorites&amp;pidp=favorites">
#         <span>
#          My Runners
#         </span>
#        </a>
#       </li>
#       <li class="dropdown hide">
#        <a aria-expanded="true" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="javascript:void(0);" id="navbar-main-dropdown">
#         More
#         <span class="caret">
#         </span>
#        </a>
#        <ul aria-labelledby="navbar-main-dropdown" class="dropdown-menu">
#        </ul>
#       </li>
#       <script type="text/javascript">
#        jQuery("#navbar-main-dropdown").dropdown();
#                 var menuResizeHandler = function () {
#                     var container   = jQuery(".navbar-main .container");
#                     var navbar   = jQuery(".navbar-main .nav");
#                     var currentWidth = 0;
#                     var dropdown = navbar.find("li.dropdown");
#                     // quickly show it and get the width
#                     dropdown.removeClass("hide");
#                     var dropdownWidth = dropdown.width();
#                     var quicksearchWidth = jQuery(".navbar-main .quicksearch-form").width();
#                     currentWidth += quicksearchWidth;
#                     var menuEntries = navbar.find("li:not(.dropdown)");
#                     menuEntries.each(function (i) {
#                         navbar.append(this);
#                     });
#                     navbar.append(dropdown);
#                     dropdown.addClass("hide").removeClass("active");
#
#                     var maxWidth = container.width();
#                     menuEntries.each(function (i) {
#                         currentWidth += jQuery(this).width();
#
#                         var next = false;
#                         if (typeof menuEntries[i+1] !== "undefined") {
#                             next = menuEntries[i+1];
#                         }
#                         var currentIsAboveMaxWidth = (currentWidth > maxWidth);
#                         var currentIsNotLastAndPlusDropdownIsAboveMaxWidth = ((currentWidth + dropdownWidth > maxWidth) && i != menuEntries.length-1);
#                         var currentPlusNextIsAboveMaxWidth = (next && currentWidth + jQuery(next).width() > maxWidth);
#                         //console.log("%s: width: %s, is above: %s, notlast: %s, plusnext: %s", jQuery(this).text(), currentWidth, currentIsAboveMaxWidth, currentIsNotLastAndPlusDropdownIsAboveMaxWidth, currentPlusNextIsAboveMaxWidth)
#                         if(currentIsAboveMaxWidth || currentIsNotLastAndPlusDropdownIsAboveMaxWidth || currentPlusNextIsAboveMaxWidth) {
#                             jQuery(this).find("a").popover("destroy");
#                             dropdown.find("ul").append(this);
#                             dropdown.removeClass("hide");
#                             if (jQuery(this).hasClass("active")) {
#                                 dropdown.addClass("active");
#                             }
#                         }
#                     });
#
#                 };
#                 jQuery(document).on("ready", menuResizeHandler);
#                 var lastWidth = 0;
#                 jQuery(window).on("resize", function () {
#                     lastWidth = window.innerWidth;
#                     setTimeout(function () {
#                         if (lastWidth == window.innerWidth) {
#                             menuResizeHandler();
#                         }
#                     }, 100);
#                 });
#       </script>
#      </ul>
#     </div>
#    </nav>
#    <!-- menu end -->
#   </section>
#   <section class="section-main">
#    <div class="container" id="main-content">
#     <div class="row">
#      <div class="cbox-main pid-detail col-xs-12" id="cbox-main">
#       <!-- cbox include start -->
#       <div class="detail">
#        <h2>
#         Person Details
#        </h2>
#        <div class="row detail-content">
#         <div class="col col-xs-12 col-md-6 detail-channel channel-left">
#          <div class="detail-box box-general">
#           <h3>
#            Participant
#           </h3>
#           <table class="table table-condensed">
#            <tbody>
#             <tr class="f-__fullname">
#              <th class="desc">
#               Name (CTZ)
#              </th>
#              <td class="f-__fullname last">
#               Tura Abdiwak, Seifu (ETH)
#              </td>
#             </tr>
#             <tr class="list-highlight f-age_class">
#              <th class="desc">
#               Age Group
#              </th>
#              <td class="f-age_class last">
#               20-24
#              </td>
#             </tr>
#             <tr class="f-start_no_text">
#              <th class="desc">
#               Bib Number
#              </th>
#              <td class="f-start_no_text last">
#               3
#              </td>
#             </tr>
#             <tr class="list-highlight f-__city_state">
#              <th class="desc">
#               City, State
#              </th>
#              <td class="f-__city_state last">
#               Iseo
#              </td>
#             </tr>
#             <tr class="f-display_name_short">
#              <th class="desc">
#               Short
#              </th>
#              <td class="f-display_name_short last">
#               ST
#              </td>
#             </tr>
#            </tbody>
#           </table>
#          </div>
#          <div class="detail-box box-other">
#           <h3>
#            Race Info
#           </h3>
#           <table class="table table-condensed">
#            <tbody>
#             <tr class="f-starttime_net">
#              <th class="desc">
#               Start Time
#              </th>
#              <td class="f-starttime_net last">
#               07:30:00
#              </td>
#             </tr>
#            </tbody>
#           </table>
#          </div>
#          <div class="detail-box box-totals">
#           <h3>
#            Totals
#           </h3>
#           <table class="table table-condensed">
#            <tbody>
#             <tr class="f-place_all">
#              <th class="desc">
#               Place Gender
#              </th>
#              <td class="f-place_all last">
#               1
#              </td>
#             </tr>
#             <tr class="list-highlight f-place_age">
#              <th class="desc">
#               Place Age Group
#              </th>
#              <td class="f-place_age last">
#               1
#              </td>
#             </tr>
#             <tr class="f-place_nosex">
#              <th class="desc">
#               Place Overall
#              </th>
#              <td class="f-place_nosex last">
#               1
#              </td>
#             </tr>
#             <tr class="list-highlight f-time_finish_netto">
#              <th class="desc">
#               Finish Time
#              </th>
#              <td class="f-time_finish_netto last">
#               02:06:12
#              </td>
#             </tr>
#            </tbody>
#           </table>
#          </div>
#          <div class="detail-box box-favorite">
#           <h3>
#            My Runner
#           </h3>
#           <table class="table table-condensed">
#            <tbody>
#             <tr class="f-__nix">
#              <th class="desc">
#               Add/Remove
#              </th>
#              <td class="f-__nix last">
#               <a class="icon l" href="?content=detail&amp;idp=LSMG963824DD5C&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=LSMG963824DD5C">
#                <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#               </a>
#              </td>
#             </tr>
#            </tbody>
#           </table>
#          </div>
#         </div>
#         <div class="col col-xs-12 col-md-6 detail-channel channel-right">
#          <div class="detail-box box-splits">
#           <h3>
#            Splits
#            <div class="btn-group btn-group-xs pull-right" role="group">
#             <button class="btn btn-default colgroup-switch-colgroup-splits colgroup-switch-colgroup-splits-imperial" onclick="switchColGroupcolgroupsplits('colgroup-splits', 'colgroup-splits-imperial');">
#              Miles
#             </button>
#             <button class="btn btn-default colgroup-switch-colgroup-splits colgroup-switch-colgroup-splits-metric" onclick="switchColGroupcolgroupsplits('colgroup-splits', 'colgroup-splits-metric');">
#              Kilometers
#             </button>
#            </div>
#           </h3>
#           <script>
#            function switchColGroupcolgroupsplits(group, item) {
#                         jQuery("." + group).hide()
#                         jQuery(".colgroup-switch-" + group).removeClass("active");
#                         jQuery("." + item).show()
#                         jQuery(".colgroup-switch-" + item).addClass("active");
#                     }
#
#                     jQuery(document).ready(function() {
#                         switchColGroupcolgroupsplits("colgroup-splits", "colgroup-splits-imperial");
#                     });
#           </script>
#           <div class="table-responsive">
#            <table class="table table-condensed table-striped">
#             <thead>
#              <tr>
#               <th class="desc">
#                Split
#               </th>
#               <th class="time_day">
#                Time Of Day
#               </th>
#               <th class="time">
#                Time
#               </th>
#               <th class="diff">
#                Diff
#               </th>
#               <th class="min_km right opt colgroup-splits colgroup-splits-metric">
#                min/km
#               </th>
#               <th class="kmh colgroup-splits colgroup-splits-metric">
#                km/h
#               </th>
#               <th class="min_mile right opt colgroup-splits colgroup-splits-imperial">
#                min/mile
#               </th>
#               <th class="miles_h right opt colgroup-splits colgroup-splits-imperial last">
#                miles/h
#               </th>
#              </tr>
#             </thead>
#             <tbody>
#              <tr class="f-time_05">
#               <th class="desc">
#                05K
#               </th>
#               <td class="time_day">
#                07:44:43AM
#               </td>
#               <td class="time">
#                00:14:43
#               </td>
#               <td class="diff">
#                14:43
#               </td>
#               <td class="min_km right opt colgroup-splits colgroup-splits-metric">
#                02:57
#               </td>
#               <td class="kmh colgroup-splits colgroup-splits-metric">
#                20.40
#               </td>
#               <td class="min_mile right opt colgroup-splits colgroup-splits-imperial">
#                04:44
#               </td>
#               <td class="miles_h right opt colgroup-splits colgroup-splits-imperial last">
#                12.68
#               </td>
#              </tr>
#              <tr class="list-highlight f-time_10">
#               <th class="desc">
#                10K
#               </th>
#               <td class="time_day">
#                07:59:15AM
#               </td>
#               <td class="time">
#                00:29:15
#               </td>
#               <td class="diff">
#                14:32
#               </td>
#               <td class="min_km right opt colgroup-splits colgroup-splits-metric">
#                02:55
#               </td>
#               <td class="kmh colgroup-splits colgroup-splits-metric">
#                20.64
#               </td>
#               <td class="min_mile right opt colgroup-splits colgroup-splits-imperial">
#                04:41
#               </td>
#               <td class="miles_h right opt colgroup-splits colgroup-splits-imperial last">
#                12.83
#               </td>
#              </tr>
#              <tr class="f-time_15">
#               <th class="desc">
#                15K
#               </th>
#               <td class="time_day">
#                08:14:21AM
#               </td>
#               <td class="time">
#                00:44:21
#               </td>
#               <td class="diff">
#                15:06
#               </td>
#               <td class="min_km right opt colgroup-splits colgroup-splits-metric">
#                03:02
#               </td>
#               <td class="kmh colgroup-splits colgroup-splits-metric">
#                19.87
#               </td>
#               <td class="min_mile right opt colgroup-splits colgroup-splits-imperial">
#                04:52
#               </td>
#               <td class="miles_h right opt colgroup-splits colgroup-splits-imperial last">
#                12.35
#               </td>
#              </tr>
#              <tr class="list-highlight f-time_20">
#               <th class="desc">
#                20K
#               </th>
#               <td class="time_day">
#                08:29:13AM
#               </td>
#               <td class="time">
#                00:59:13
#               </td>
#               <td class="diff">
#                14:52
#               </td>
#               <td class="min_km right opt colgroup-splits colgroup-splits-metric">
#                02:59
#               </td>
#               <td class="kmh colgroup-splits colgroup-splits-metric">
#                20.17
#               </td>
#               <td class="min_mile right opt colgroup-splits colgroup-splits-imperial">
#                04:48
#               </td>
#               <td class="miles_h right opt colgroup-splits colgroup-splits-imperial last">
#                12.53
#               </td>
#              </tr>
#              <tr class="f-time_52">
#               <th class="desc">
#                HALF
#               </th>
#               <td class="time_day">
#                08:32:29AM
#               </td>
#               <td class="time">
#                01:02:29
#               </td>
#               <td class="diff">
#                03:16
#               </td>
#               <td class="min_km right opt colgroup-splits colgroup-splits-metric">
#                02:59
#               </td>
#               <td class="kmh colgroup-splits colgroup-splits-metric">
#                20.17
#               </td>
#               <td class="min_mile right opt colgroup-splits colgroup-splits-imperial">
#                04:48
#               </td>
#               <td class="miles_h right opt colgroup-splits colgroup-splits-imperial last">
#                12.53
#               </td>
#              </tr>
#              <tr class="list-highlight f-time_25">
#               <th class="desc">
#                25K
#               </th>
#               <td class="time_day">
#                08:44:42AM
#               </td>
#               <td class="time">
#                01:14:42
#               </td>
#               <td class="diff">
#                12:13
#               </td>
#               <td class="min_km right opt colgroup-splits colgroup-splits-metric">
#                03:08
#               </td>
#               <td class="kmh colgroup-splits colgroup-splits-metric">
#                19.16
#               </td>
#               <td class="min_mile right opt colgroup-splits colgroup-splits-imperial">
#                05:03
#               </td>
#               <td class="miles_h right opt colgroup-splits colgroup-splits-imperial last">
#                11.91
#               </td>
#              </tr>
#              <tr class="f-time_30">
#               <th class="desc">
#                30K
#               </th>
#               <td class="time_day">
#                09:00:06AM
#               </td>
#               <td class="time">
#                01:30:06
#               </td>
#               <td class="diff">
#                15:24
#               </td>
#               <td class="min_km right opt colgroup-splits colgroup-splits-metric">
#                03:05
#               </td>
#               <td class="kmh colgroup-splits colgroup-splits-metric">
#                19.48
#               </td>
#               <td class="min_mile right opt colgroup-splits colgroup-splits-imperial">
#                04:58
#               </td>
#               <td class="miles_h right opt colgroup-splits colgroup-splits-imperial last">
#                12.11
#               </td>
#              </tr>
#              <tr class="list-highlight f-time_35">
#               <th class="desc">
#                35K
#               </th>
#               <td class="time_day">
#                09:15:01AM
#               </td>
#               <td class="time">
#                01:45:01
#               </td>
#               <td class="diff">
#                14:55
#               </td>
#               <td class="min_km right opt colgroup-splits colgroup-splits-metric">
#                02:59
#               </td>
#               <td class="kmh colgroup-splits colgroup-splits-metric">
#                20.12
#               </td>
#               <td class="min_mile right opt colgroup-splits colgroup-splits-imperial">
#                04:48
#               </td>
#               <td class="miles_h right opt colgroup-splits colgroup-splits-imperial last">
#                12.50
#               </td>
#              </tr>
#              <tr class="f-time_40">
#               <th class="desc">
#                40K
#               </th>
#               <td class="time_day">
#                09:29:44AM
#               </td>
#               <td class="time">
#                01:59:44
#               </td>
#               <td class="diff">
#                14:43
#               </td>
#               <td class="min_km right opt colgroup-splits colgroup-splits-metric">
#                02:57
#               </td>
#               <td class="kmh colgroup-splits colgroup-splits-metric">
#                20.39
#               </td>
#               <td class="min_mile right opt colgroup-splits colgroup-splits-imperial">
#                04:45
#               </td>
#               <td class="miles_h right opt colgroup-splits colgroup-splits-imperial last">
#                12.67
#               </td>
#              </tr>
#              <tr class="list-highlight f-time_finish_netto highlight">
#               <th class="desc">
#                Finish
#               </th>
#               <td class="time_day">
#                09:36:12AM
#               </td>
#               <td class="time">
#                02:06:12
#               </td>
#               <td class="diff">
#                06:28
#               </td>
#               <td class="min_km right opt colgroup-splits colgroup-splits-metric">
#                02:58
#               </td>
#               <td class="kmh colgroup-splits colgroup-splits-metric">
#                20.33
#               </td>
#               <td class="min_mile right opt colgroup-splits colgroup-splits-imperial">
#                04:45
#               </td>
#               <td class="miles_h right opt colgroup-splits colgroup-splits-imperial last">
#                12.64
#               </td>
#              </tr>
#             </tbody>
#            </table>
#           </div>
#           <small class="table-responsive-hint hidden-sm hidden-md hidden-lg text-muted">
#            Swipe the table to see all the content.
#           </small>
#          </div>
#          <div class="detail-box box-features">
#           <h3>
#            Features
#           </h3>
#           <table class="table table-condensed">
#            <tbody>
#             <tr>
#              <td class="last">
#               <div class="row">
#                <div class="feature col-xs-12 col-sm-6">
#                 <span>
#                  <a class="btn img" href="http://www.marathonfoto.com/In?RaceOID=12852021M1&amp;LastName=Tura Abdiwak&amp;BibNumber=3" onclick="ga_track.push(['_trackPageview', '/2021_chicago/outgoing/MarathonFotoRaceDayPhotos']); ga_track.push(['_trackEvent', '2021_chicago_Features', 'Feature', 'MarathonFotoRaceDayPhotos']);" style="padding:0px;" target="_blank">
#                   <img alt="MarathonFoto Race Day Photos" class="img-responsive" src="//assets.mikatiming.com/img/mt/results/default/images/button_photo.svg" style="vertical-align:middle;" title="MarathonFoto Race Day Photos"/>
#                  </a>
#                  <a class="btn btn-primary btn-block" href="http://www.marathonfoto.com/In?RaceOID=12852021M1&amp;LastName=Tura Abdiwak&amp;BibNumber=3" onclick="ga_track.push(['_trackPageview', '/2021_chicago/outgoing/MarathonFotoRaceDayPhotos']); ga_track.push(['_trackEvent', '2021_chicago_Features', 'Feature', 'MarathonFotoRaceDayPhotos']);" target="_blank">
#                   MarathonFoto Race Day Photos
#                  </a>
#                 </span>
#                </div>
#                <div class="feature col-xs-12 col-sm-6">
#                 <span>
#                  <a class="btn img" href="https://organizations.hakuapp.com/organizations/9b4ada1d9a92ebcf8016/event_products/7622/?single_product=true" onclick="ga_track.push(['_trackPageview', '/2021_chicago/outgoing/2021ResultsBook']); ga_track.push(['_trackEvent', '2021_chicago_Features', 'Feature', '2021ResultsBook']);" style="padding:0px;" target="_blank">
#                   <img alt="2021 Results Book" class="img-responsive" src="//assets.mikatiming.com/img/mt/results/default/images/button_certificate.svg" style="vertical-align:middle;" title="2021 Results Book"/>
#                  </a>
#                  <a class="btn btn-primary btn-block" href="https://organizations.hakuapp.com/organizations/9b4ada1d9a92ebcf8016/event_products/7622/?single_product=true" onclick="ga_track.push(['_trackPageview', '/2021_chicago/outgoing/2021ResultsBook']); ga_track.push(['_trackEvent', '2021_chicago_Features', 'Feature', '2021ResultsBook']);" target="_blank">
#                   2021 Results Book
#                  </a>
#                 </span>
#                </div>
#               </div>
#              </td>
#             </tr>
#            </tbody>
#           </table>
#          </div>
#         </div>
#        </div>
#        <!-- detail-content -->
#        <div style="clear:both">
#        </div>
#       </div>
#       <!-- detail -->
#       <div class="row buttons">
#        <div class="col-xs-12 hidden-sm hidden-md hidden-lg" style="margin-bottom:5px">
#         <div class="" id="details-sharer-xs">
#         </div>
#        </div>
#        <script type="text/javascript">
#         jQuery(document).ready(function($){
#                             if (typeof require != "undefined") {
#                                 require(["Mika/Sharer/Sharer"], function (Sharer) {
#                                     new Sharer({
#                                         target: "#details-sharer-xs",
#                                         buttonSize: "md",
#                                         shareUrl: "https://results.chicagomarathon.com/2021/?content=detail&event=MAR&idp=LSMG963824DD5C&lang=EN_CAP&num_results=50&pid=list&pidp=start&search[sex]=M&search[age_class]=%25&id=LSMG963824DD5C",
#                                         shareText: ""
#                                     });
#                                 });
#                             }
#                         });
#        </script>
#        <div class="col-sm-6 col-xs-12">
#         <div aria-label="" class="btn-toolbar" role="toolbar">
#          <div class="btn-group" role="group">
#           <a class="btn btn-default" href="/2021/?pid=list&amp;fpid=list&amp;lang=EN_CAP&amp;event=MAR&amp;num_results=50&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#            Back
#           </a>
#           <a class="btn btn-default" href="#" onclick="open_print('?print=1&amp;fpid=list&amp;content=detail&amp;event=MAR&amp;idp=LSMG963824DD5C&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;pidp=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;id=LSMG963824DD5C');">
#            Print
#           </a>
#           <a class="btn btn-default detail-results-request" href="?ref=%3Ffpid%3Dlist%26amp%3Bcontent%3Ddetail%26amp%3Bevent%3DMAR%26amp%3Bidp%3DLSMG963824DD5C%26amp%3Blang%3DEN_CAP%26amp%3Bnum_results%3D50%26amp%3Bpid%3Dlist%26amp%3Bpidp%3Dstart%26amp%3Bsearch%255Bsex%255D%3DM%26amp%3Bsearch%255Bage_class%255D%3D%2525%26amp%3Bid%3DLSMG963824DD5C&amp;event=MAR&amp;meeting=9TGG9638F1&amp;id=LSMG963824DD5C&amp;lang=EN_CAP&amp;pid=request_form">
#            Results Request Form
#           </a>
#          </div>
#          <!-- btn-group -->
#         </div>
#         <!-- btn-toolbar -->
#        </div>
#        <!-- col -->
#        <div class="col-sm-6 hidden-xs">
#         <div class="pull-right" id="details-sharer">
#         </div>
#        </div>
#        <script type="text/javascript">
#         jQuery(document).ready(function($){
#                             if (typeof require != "undefined") {
#                                 require(["Mika/Sharer/Sharer"], function (Sharer) {
#                                     new Sharer({
#                                         target: "#details-sharer",
#                                         shareUrl: "https://results.chicagomarathon.com/2021/?content=detail&event=MAR&idp=LSMG963824DD5C&lang=EN_CAP&num_results=50&pid=list&pidp=start&search[sex]=M&search[age_class]=%25&id=LSMG963824DD5C",
#                                         shareText: ""
#                                     });
#                                 });
#                             }
#                         });
#        </script>
#       </div>
#       <!-- row -->
#       <!-- cbox include end -->
#      </div>
#     </div>
#     <!-- row -->
#    </div>
#    <!-- container main-content -->
#   </section>
#   <!-- section-main -->
#   <!-- main end -->
#   <!-- footer start -->
#   <footer>
#    <div class="container">
#     <div class="row">
#      <div class="footer-box legal-footer" id="pid-detail">
#       <div class="col-xs-12">
#        <a class="pull-right" href="https://www.mikatiming.de/">
#         mika:timing GmbH © 2022
#        </a>
#        <a href="https://www.mikatiming.de/en/service/legal-notice/">
#         Legal Notice
#        </a>
#        |
#        <a href="https://www.mikatiming.de/en/service/legal-notice/privacy-policy/">
#         Privacy Policy
#        </a>
#       </div>
#      </div>
#     </div>
#     <!-- row end -->
#    </div>
#    <!-- container end -->
#   </footer>
#   <!-- footer section end -->
#   <div class="popup-info" id="popup-info" style="display:none;">
#   </div>
#   <div class="popup" id="popup" style="display:none;">
#   </div>
#  </body>
# </html>
# <!-- footer end -->

# %% [markdown]
# Spotting from content, we notice that **each detail information** is wrapped with the tag **td** and **specify class name** such as **f-__fullname last** for name, **f-age_class last** for age group, and etc.
#
# Therefore , we manually get them with the method `find` and `get_text` of BeautifulSoup:

# %%
soup_1.find("td",class_="f-__fullname last").get_text()
# Out:
# 'Tura Abdiwak, Seifu (ETH)'

# %%
soup_1.find("td",class_="f-age_class last").get_text()
# Out:
# '20-24'

# %%
soup_1.find("td",class_="f-start_no_text last").get_text()
# Out:
# '3'

# %%
soup_1.find("td",class_="f-__city_state last").get_text()
# Out:
# 'Iseo'

# %%
soup_1.find("td",class_="f-display_name_short last").get_text()
# Out:
# 'ST'

# %%
times=soup_1.find_all("td",class_="time")
times
# Out:
# [<td class="time">00:14:43</td>,
#  <td class="time">00:29:15</td>,
#  <td class="time">00:44:21</td>,
#  <td class="time">00:59:13</td>,
#  <td class="time">01:02:29</td>,
#  <td class="time">01:14:42</td>,
#  <td class="time">01:30:06</td>,
#  <td class="time">01:45:01</td>,
#  <td class="time">01:59:44</td>,
#  <td class="time">02:06:12</td>]

# %% [markdown]
# For the **splits** information, it is different. We have the **time** for **10** splits and each of them is still wrapped by tag **td**. Hence, we will **iterate** through each of them and get the text:

# %%
for i in times:
       print (i.get_text())
# Out:
# 00:14:43
# 00:29:15
# 00:44:21
# 00:59:13
# 01:02:29
# 01:14:42
# 01:30:06
# 01:45:01
# 01:59:44
# 02:06:12

# %% [markdown]
# And, that is how we obtain all the information for **1 runner**:. We now generalize our process for **50 runners**:

# %% [markdown]
# A dataframe is **list of dictionaries**. Therefore, we will have a list `all_runners` and append to it **dictionary** of information of **each runner** for every **iteration**:

# %%
splits=["05K","10K","15K","20K","HALF","25K","30K","35K","40K","Finish"]

# %% [markdown]
# In addition, in order to limit the usage of web sever, we add a delay of 2 seconds with the library **sleep*:

# %%
from time import sleep

# %%
#initialize list of runners
all_runners=[]
#iterate through every person in the runners array
for person in runners:
    #initialize the dictionary which each key is the name of information and value is the information
    listing={}
    #obtain the personal link
    incomplete_link=person.find('a').get('href')
    #complete the link by adding the header https://results.chicagomarathon.com/2021/ 
    link="https://results.chicagomarathon.com/2021/"+incomplete_link
    #using request to send a GET to have the HTML content
    info=requests.get(link).text
    #parse with BeautifulSoup to start the scrapping process
    soup= BeautifulSoup(info)
    # get the list of times of 10 splits
    time_record=soup.find_all("td",class_="time")
    #get all the information for name, age group, bib number, city, short and add to the dictionary
    listing["Name (CTZ)"]=soup.find("td",class_="f-__fullname last").get_text()
    listing["Age Group"]=soup.find("td",class_="f-age_class last").get_text()
    listing["Bib Number"]=soup.find("td",class_="f-start_no_text last").get_text()
    listing["City, State"]=soup.find("td",class_="f-__city_state last").get_text()
    listing["Short"]=soup.find("td",class_="f-display_name_short last").get_text()
    #match the splits to the corresponding time and add them to the dictionary as well
    l=range(len(splits))
    for i in l:
        listing[splits[i]]=time_record[i].get_text()
    #add the dictionary to the list of runners
    all_runners.append(listing)
    #stop for 2 seconds before getting to the next runner
    sleep(2)

# %% [markdown]
# Eventually, thanks to **Pandas** library, we will view our **final** result better:

# %%
import pandas as pd

# %%
df=pd.DataFrame(all_runners)
df
# Out:
#                       Name (CTZ) Age Group Bib Number       City, State Short  \
# 0      Tura Abdiwak, Seifu (ETH)     20-24          3              Iseo    ST
# 1              Rupp, Galen (USA)     35-39          9          Portland    GR
# 2           Kiptanui, Eric (KEN)     30-34          7              Iten    EK
# 3            Suzuki, Kengo (JPN)     25-29          5  Chiba City Chiba    KS
# 4     Tamru Aredo, Shifera (ETH)     20-24          6              Iseo    ST
# 5            Mickow, Colin (USA)     30-34         15            Oswego    CM
# 6           Montanez, Nico (USA)     25-29         22     Mammoth Lakes    NM
# 7   Kipyego, Reuben Kiprop (KEN)     25-29          2          Kapsabet    RK
# 8            Fischer, Reed (USA)     25-29         30           Boulder    RF
# 9         Given, Wilkerson (USA)     30-34         16           Atlanta    WG
# 10        Panning, Zachery (USA)     25-29         35        Lake Orion    ZP
# 11          Thomson, Jacob (USA)     25-29         37         Flagstaff    JT
# 12          Young, Clayton (USA)     25-29         31             Provo    CY
